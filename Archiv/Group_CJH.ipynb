# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import *
import plotly_express as px

# %%
from IPython.core.display import display, HTML

display(HTML("<style>.container { width:100% !important; }</style>")) # Increase cell width
display(HTML("<style>.rendered_html { font-size: 16px; }</style>")) # Increase font size
# Out:
# C:\Users\JuanHorrillo\AppData\Local\Temp\ipykernel_40488\4206306667.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
# <style>.container { width:100% !important; }</style>
# <style>.rendered_html { font-size: 16px; }</style>

# %%
df = pd.read_csv('madrid_transactions.csv', delimiter=',', skiprows=0, low_memory=False)

# %%
df.head()
# Out:
#    Unnamed: 0  amount            category customer_country    daytime  hour  \
# 0           1   33.46     Fashion & Shoes               GB      Night    21
# 1           2   59.97     Fashion & Shoes               GB  Afternoon    16
# 2           3   49.99     Fashion & Shoes               CN    Evening    17
# 3           4    5.95     Fashion & Shoes               GB    Evening    17
# 4           5   16.65  Bars & restaurants               DK      Night    22
#
#              tx_date_proc    weekday
# 0  2012-03-01 21:51:54+00  thursday
# 1  2012-03-02 16:12:52+00  friday
# 2  2012-03-02 17:34:01+00  friday
# 3  2012-03-01 17:43:29+00  thursday
# 4  2012-03-01 22:47:52+00  thursday

# %%
from pandas_profiling import ProfileReport
report = ProfileReport(df, minimal=False)
report
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.2.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-12-05 17:11:21.480366&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
cols_for_distrib = df.columns[1:7].tolist()
sns.pairplot(df[cols_for_distrib], corner=True)

# %%
ggplot(df, aes(x='category',y='amount'))+geom_col(aes(fill='customer_country'))+coord_flip()
# Out:
# <ggplot: (139692060109)>

# %%
ggplot(df, aes(x='customer_country',y='amount'))+geom_col(aes(fill='category')) +coord_flip()+theme(aspect_ratio=5)
# Out:
# <ggplot: (139693755347)>

# %%
    # %matplotlib inline
    plt.rcParams['figure.figsize']=20,20

# %%
sns.violinplot(data=df,x='amount',y='category',hue='weekday',split=True)
#v.fig.set_size_inches(15,15)
# Out:
# <AxesSubplot:xlabel='amount', ylabel='category'>

# %%
sns.violinplot(data=df,x='amount',y='category',hue='weekday',split=True, scale='count')
# Out:
# <AxesSubplot:xlabel='amount', ylabel='category'>
